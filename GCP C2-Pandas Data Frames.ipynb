# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('E:\Data Science\Datasets\Marks.csv')

# %%
df.head()
# Out:
#    S.N        Roll                        Name    T1  T2  End sem    TA Grades
# 0    1  BT20CSE001            ANIKET B AGRAWAL  22.0  17     24.0  18.0     AA
# 1    2  BT20CSE002          KATTA RAKESH REDDY  12.0  13     23.0  11.0     BC
# 2    3  BT20CSE003  CHIRAG RAJKUMAR BHANDAKKAR  20.0  15     18.0  18.0     BB
# 3    4  BT20CSE004     Tejas Rajendra Donadkar  22.5  17     23.0  17.0     AB
# 4    5  BT20CSE005  Utkarsh Sanjay Vishwakarma  23.0  17     22.5   4.0     BC

# %%
df.tail()
# Out:
#      S.N        Roll                   Name    T1  T2  End sem    TA Grades
# 186  187  BT20CSE207         Swapnil  Kabir  19.5  15     24.0  17.0     AB
# 187  188  BT19CSE101                NANDEEP   7.0  12      5.0   5.0     FF
# 188  189  Bt18cse039          Aatram Sujith   4.0  14     11.5   5.5     DD
# 189  190  BT20CSE096       VAIBHAV  GOKLANI   0.0   5      5.0   0.0     FF
# 190  191  BT20CSE195  SHUBHANGI ASHOK RASAL   0.0   9      1.0   0.0     FF

# %%
df.shape
# Out:
# (191, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.N      191 non-null    int64
#  1   Roll     191 non-null    object
#  2   Name     191 non-null    object
#  3   T1       187 non-null    float64
#  4   T2       191 non-null    int64
#  5   End sem  188 non-null    float64
#  6   TA       191 non-null    float64
#  7   Grades   191 non-null    object
# dtypes: float64(3), int64(2), object(3)
# memory usage: 12.1+ KB

# %%
df.dtypes
# Out:
# S.N          int64
# Roll        object
# Name        object
# T1         float64
# T2           int64
# End sem    float64
# TA         float64
# Grades      object
# dtype: object

# %%
df.describe()
# Out:
#             S.N          T1          T2     End sem          TA
# count  191.0000  187.000000  191.000000  188.000000  191.000000
# mean    96.0000   15.192513   13.890052   18.984043   14.782723
# std     55.2811    5.970388    3.417210    5.607459    4.314744
# min      1.0000    0.000000    0.000000    0.000000    0.000000
# 25%     48.5000   11.000000   12.000000   16.500000   13.000000
# 50%     96.0000   16.000000   14.000000   20.500000   17.000000
# 75%    143.5000   20.000000   17.000000   23.000000   18.000000
# max    191.0000   26.000000   20.000000   26.500000   19.000000

# %%
df['T1'].head()
# Out:
# 0    22.0
# 1    12.0
# 2    20.0
# 3    22.5
# 4    23.0
# Name: T1, dtype: float64

# %%
df.T1.head()
# Out:
# 0    22.0
# 1    12.0
# 2    20.0
# 3    22.5
# 4    23.0
# Name: T1, dtype: float64

# %%
df['End sem'].head()
# Out:
# 0    24.0
# 1    23.0
# 2    18.0
# 3    23.0
# 4    22.5
# Name: End sem, dtype: float64

# %%
cols=['Roll','Name']
df[cols].head()
# Out:
#          Roll                        Name
# 0  BT20CSE001            ANIKET B AGRAWAL
# 1  BT20CSE002          KATTA RAKESH REDDY
# 2  BT20CSE003  CHIRAG RAJKUMAR BHANDAKKAR
# 3  BT20CSE004     Tejas Rajendra Donadkar
# 4  BT20CSE005  Utkarsh Sanjay Vishwakarma

# %%
df.iloc[2]
# Out:
# S.N                                 3
# Roll                       BT20CSE003
# Name       CHIRAG RAJKUMAR BHANDAKKAR
# T1                               20.0
# T2                                 15
# End sem                          18.0
# TA                               18.0
# Grades                             BB
# Name: 2, dtype: object

# %%
df['Roll']=='Bt18cse039'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 186    False
# 187    False
# 188     True
# 189    False
# 190    False
# Name: Roll, Length: 191, dtype: bool

# %%
c=df['Roll']=='Bt18cse039'
df[c]
# Out:
#      S.N        Roll           Name   T1  T2  End sem   TA Grades
# 188  189  Bt18cse039  Aatram Sujith  4.0  14     11.5  5.5     DD

# %%
c1=df['Grades']=='AA'
df[c1]
# Out:
#      S.N        Roll                      Name    T1  T2  End sem    TA Grades
# 0      1  BT20CSE001          ANIKET B AGRAWAL  22.0  17     24.0  18.0     AA
# 6      7  BT20CSE007            SATYAM  SHUKLA  22.0  17     23.5  18.0     AA
# 30    31  BT20CSE033          MANISHA  KORANGA  20.0  19     23.5  19.0     AA
# 36    37  BT20CSE039      Paras Yashwant Patle  26.0  15     23.0  17.0     AA
# 50    51  BT20CSE054                AMBUJ  RAJ  23.0  19     24.5  17.0     AA
# 55    56  BT20CSE060                  Shivam    26.0  15     24.0  18.0     AA
# 72    73  BT20CSE078             Garvit  Verma  18.5  17     26.0  18.0     AA
# 97    98  BT20CSE105  DEEP LALITKUMAR PANCHANI  20.0  18     25.0  18.0     AA
# 107  108  BT20CSE115          Harsh  Upadhayay  20.0  20     24.0  18.0     AA
# 110  111  BT20CSE118        ARUSHI  SRIVASTAVA  20.5  17     26.5  18.0     AA
# 133  134  BT20CSE144           Anukalp  Pandey  19.0  18     23.0  18.0     AA
# ...

# %%
#find out how many students got end sem marks>20

# %%
c2=df['End sem']>20
df[c2]
# Out:
#      S.N        Roll                        Name    T1  T2  End sem    TA  \
# 0      1  BT20CSE001            ANIKET B AGRAWAL  22.0  17     24.0  18.0
# 1      2  BT20CSE002          KATTA RAKESH REDDY  12.0  13     23.0  11.0
# 3      4  BT20CSE004     Tejas Rajendra Donadkar  22.5  17     23.0  17.0
# 4      5  BT20CSE005  Utkarsh Sanjay Vishwakarma  23.0  17     22.5   4.0
# 5      6  BT20CSE006    Chaudhari Bhavesh Ishwar  14.0  15     23.5  16.0
# ..   ...         ...                         ...   ...  ..      ...   ...
# 181  182  BT20CSE201    PALLAVI MURLIDHAR DHAKNE  23.5  13     21.5  18.0
# 183  184  BT20CSE204             SARTHAK  MONDAL  20.5  16     25.5  18.0
# 184  185  BT20CSE205                  ASMIT  RAJ   7.0  18     23.0  17.0
# 185  186  BT20CSE206                      AMAN    14.0  13     24.0  13.0
# 186  187  BT20CSE207              Swapnil  Kabir  19.5  15     24.0  17.0
#
#     Grades
# 0       AA
# 1       BC
# 3       AB
# 4       BC
# 5       BB
# ...

# %%
df[df['End sem']>20]
# Out:
#      S.N        Roll                        Name    T1  T2  End sem    TA  \
# 0      1  BT20CSE001            ANIKET B AGRAWAL  22.0  17     24.0  18.0
# 1      2  BT20CSE002          KATTA RAKESH REDDY  12.0  13     23.0  11.0
# 3      4  BT20CSE004     Tejas Rajendra Donadkar  22.5  17     23.0  17.0
# 4      5  BT20CSE005  Utkarsh Sanjay Vishwakarma  23.0  17     22.5   4.0
# 5      6  BT20CSE006    Chaudhari Bhavesh Ishwar  14.0  15     23.5  16.0
# ..   ...         ...                         ...   ...  ..      ...   ...
# 181  182  BT20CSE201    PALLAVI MURLIDHAR DHAKNE  23.5  13     21.5  18.0
# 183  184  BT20CSE204             SARTHAK  MONDAL  20.5  16     25.5  18.0
# 184  185  BT20CSE205                  ASMIT  RAJ   7.0  18     23.0  17.0
# 185  186  BT20CSE206                      AMAN    14.0  13     24.0  13.0
# 186  187  BT20CSE207              Swapnil  Kabir  19.5  15     24.0  17.0
#
#     Grades
# 0       AA
# 1       BC
# 3       AB
# 4       BC
# 5       BB
# ...

# %%
df2=df[df['End sem']>20]

# %%
df2
# Out:
#      S.N        Roll                        Name    T1  T2  End sem    TA  \
# 0      1  BT20CSE001            ANIKET B AGRAWAL  22.0  17     24.0  18.0
# 1      2  BT20CSE002          KATTA RAKESH REDDY  12.0  13     23.0  11.0
# 3      4  BT20CSE004     Tejas Rajendra Donadkar  22.5  17     23.0  17.0
# 4      5  BT20CSE005  Utkarsh Sanjay Vishwakarma  23.0  17     22.5   4.0
# 5      6  BT20CSE006    Chaudhari Bhavesh Ishwar  14.0  15     23.5  16.0
# ..   ...         ...                         ...   ...  ..      ...   ...
# 181  182  BT20CSE201    PALLAVI MURLIDHAR DHAKNE  23.5  13     21.5  18.0
# 183  184  BT20CSE204             SARTHAK  MONDAL  20.5  16     25.5  18.0
# 184  185  BT20CSE205                  ASMIT  RAJ   7.0  18     23.0  17.0
# 185  186  BT20CSE206                      AMAN    14.0  13     24.0  13.0
# 186  187  BT20CSE207              Swapnil  Kabir  19.5  15     24.0  17.0
#
#     Grades
# 0       AA
# 1       BC
# 3       AB
# 4       BC
# 5       BB
# ...

# %%
print('Number of students have more than 20 in End sem are',df2.shape[0])
# Out:
# Number of students have more than 20 in End sem are 96

# %%
c1=df['End sem']>20
c2=df['T1']>15
df3=df[c1 & c2]

# %%
df3
# Out:
#      S.N        Roll                        Name    T1  T2  End sem    TA  \
# 0      1  BT20CSE001            ANIKET B AGRAWAL  22.0  17     24.0  18.0
# 3      4  BT20CSE004     Tejas Rajendra Donadkar  22.5  17     23.0  17.0
# 4      5  BT20CSE005  Utkarsh Sanjay Vishwakarma  23.0  17     22.5   4.0
# 6      7  BT20CSE007              SATYAM  SHUKLA  22.0  17     23.5  18.0
# 8      9  BT20CSE009             YATHARTH  ANAND  18.5  14     22.5  17.0
# ..   ...         ...                         ...   ...  ..      ...   ...
# 177  178  BT20CSE197                NAMAN  YADAV  18.0  16     23.0  17.0
# 178  179  BT20CSE198             JADAV  JITENDER  23.0  11     23.5  13.0
# 181  182  BT20CSE201    PALLAVI MURLIDHAR DHAKNE  23.5  13     21.5  18.0
# 183  184  BT20CSE204             SARTHAK  MONDAL  20.5  16     25.5  18.0
# 186  187  BT20CSE207              Swapnil  Kabir  19.5  15     24.0  17.0
#
#     Grades
# 0       AA
# 3       AB
# 4       BC
# 6       AA
# 8       AB
# ...

# %%
print(len(df3))
# Out:
# 74

# %%
df4=df[(df['End sem']>20) & (df['T1']>15)]

# %%
len(df4)
# Out:
# 74

# %%
df5=df.sort_values(by='End sem',ascending=False)

# %%
df5.tail()
# Out:
#      S.N        Roll                        Name    T1  T2  End sem    TA  \
# 126  127  BT20CSE136                Sahil  Ahmed   5.0   9      0.0   4.0
# 141  142  BT20CSE152               M PRATHIBHA     7.0   0      0.0  15.0
# 9     10  BT20CSE010       Yogesh Jitendra Lolge  14.0  15      NaN  17.0
# 10    11  BT20CSE011  TANMAYEE PRAMODGIRI GOSAVI  19.0  18      NaN  13.0
# 11    12  BT20CSE012       Dushyant Devidas Kore   4.5  13      NaN   4.0
#
#     Grades
# 126     FF
# 141     FF
# 9       BB
# 10      BB
# 11      DD

# %%
df['Grades'].value_counts()
# Out:
# BB    42
# BC    39
# AB    37
# CC    22
# AA    15
# CD    15
# FF    11
# DD    10
# Name: Grades, dtype: int64

# %%
df.Grades.unique()
# Out:
# array(['AA', 'BC', 'BB', 'AB', 'DD', 'CC', 'FF', 'CD'], dtype=object)

# %%
l=df.Grades.unique()
print(l)
print(type(l))
# Out:
# ['AA' 'BC' 'BB' 'AB' 'DD' 'CC' 'FF' 'CD']
# <class 'numpy.ndarray'>

# %%
type(l)
# Out:
# numpy.ndarray

# %%
gradedict=dict(df.Grades.value_counts())

# %%
gradedict
# Out:
# {'BB': 42,
#  'BC': 39,
#  'AB': 37,
#  'CC': 22,
#  'AA': 15,
#  'CD': 15,
#  'FF': 11,
#  'DD': 10}

# %%
gradedict['DD']
# Out:
# 10

# %%
print(gradedict)
# Out:
# {'BB': 42, 'BC': 39, 'AB': 37, 'CC': 22, 'AA': 15, 'CD': 15, 'FF': 11, 'DD': 10}

# %%
df.isnull()
# Out:
#        S.N   Roll   Name     T1     T2  End sem     TA  Grades
# 0    False  False  False  False  False    False  False   False
# 1    False  False  False  False  False    False  False   False
# 2    False  False  False  False  False    False  False   False
# 3    False  False  False  False  False    False  False   False
# 4    False  False  False  False  False    False  False   False
# ..     ...    ...    ...    ...    ...      ...    ...     ...
# 186  False  False  False  False  False    False  False   False
# 187  False  False  False  False  False    False  False   False
# 188  False  False  False  False  False    False  False   False
# 189  False  False  False  False  False    False  False   False
# 190  False  False  False  False  False    False  False   False
#
# [191 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# S.N        0
# Roll       0
# Name       0
# T1         4
# T2         0
# End sem    3
# TA         0
# Grades     0
# dtype: int64

# %%
df.dropna()
# Out:
#      S.N        Roll                        Name    T1  T2  End sem    TA  \
# 0      1  BT20CSE001            ANIKET B AGRAWAL  22.0  17     24.0  18.0
# 1      2  BT20CSE002          KATTA RAKESH REDDY  12.0  13     23.0  11.0
# 2      3  BT20CSE003  CHIRAG RAJKUMAR BHANDAKKAR  20.0  15     18.0  18.0
# 3      4  BT20CSE004     Tejas Rajendra Donadkar  22.5  17     23.0  17.0
# 4      5  BT20CSE005  Utkarsh Sanjay Vishwakarma  23.0  17     22.5   4.0
# ..   ...         ...                         ...   ...  ..      ...   ...
# 186  187  BT20CSE207              Swapnil  Kabir  19.5  15     24.0  17.0
# 187  188  BT19CSE101                     NANDEEP   7.0  12      5.0   5.0
# 188  189  Bt18cse039               Aatram Sujith   4.0  14     11.5   5.5
# 189  190  BT20CSE096            VAIBHAV  GOKLANI   0.0   5      5.0   0.0
# 190  191  BT20CSE195       SHUBHANGI ASHOK RASAL   0.0   9      1.0   0.0
#
#     Grades
# 0       AA
# 1       BC
# 2       BB
# 3       AB
# 4       BC
# ...

# %%
df['Total']=df['T1']+df['T2']+df['End sem']+df['TA']

# %%
df.head()
# Out:
#    S.N        Roll                        Name    T1  T2  End sem    TA  \
# 0    1  BT20CSE001            ANIKET B AGRAWAL  22.0  17     24.0  18.0
# 1    2  BT20CSE002          KATTA RAKESH REDDY  12.0  13     23.0  11.0
# 2    3  BT20CSE003  CHIRAG RAJKUMAR BHANDAKKAR  20.0  15     18.0  18.0
# 3    4  BT20CSE004     Tejas Rajendra Donadkar  22.5  17     23.0  17.0
# 4    5  BT20CSE005  Utkarsh Sanjay Vishwakarma  23.0  17     22.5   4.0
#
#   Grades  Total
# 0     AA   81.0
# 1     BC   59.0
# 2     BB   71.0
# 3     AB   79.5
# 4     BC   66.5

# %%
df6=df.sort_values(by='Total',ascending=False)

# %%
df.head()
# Out:
#    S.N        Roll                        Name    T1  T2  End sem    TA  \
# 0    1  BT20CSE001            ANIKET B AGRAWAL  22.0  17     24.0  18.0
# 1    2  BT20CSE002          KATTA RAKESH REDDY  12.0  13     23.0  11.0
# 2    3  BT20CSE003  CHIRAG RAJKUMAR BHANDAKKAR  20.0  15     18.0  18.0
# 3    4  BT20CSE004     Tejas Rajendra Donadkar  22.5  17     23.0  17.0
# 4    5  BT20CSE005  Utkarsh Sanjay Vishwakarma  23.0  17     22.5   4.0
#
#   Grades  Total
# 0     AA   81.0
# 1     BC   59.0
# 2     BB   71.0
# 3     AB   79.5
# 4     BC   66.5

# %%
a=np.array([10,20,30,40])
s=pd.Series()
s
# Out:
# C:\Users\Prem\AppData\Local\Temp\ipykernel_2156\3457638970.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s=pd.Series()
# Series([], dtype: float64)

# %%
s=pd.Series(a)
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int32

# %%
d={'a':10,'b':20,'c':30,'d':40}

# %%
ds=pd.Series(d)
ds
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}

# %%
marks=[45,87,94,100]
rollno=[2,3,4,5]
s=pd.Series(data=marks,index=rollno)

print(s)
# Out:
# 2     45
# 3     87
# 4     94
# 5    100
# dtype: int64

# %%
df.describe()
# Out:
#             S.N          T1          T2     End sem          TA       Total
# count  191.0000  187.000000  191.000000  188.000000  191.000000  184.000000
# mean    96.0000   15.192513   13.890052   18.984043   14.782723   62.891304
# std     55.2811    5.970388    3.417210    5.607459    4.314744   15.841915
# min      1.0000    0.000000    0.000000    0.000000    0.000000   10.000000
# 25%     48.5000   11.000000   12.000000   16.500000   13.000000   55.500000
# 50%     96.0000   16.000000   14.000000   20.500000   17.000000   66.500000
# 75%    143.5000   20.000000   17.000000   23.000000   18.000000   74.500000
# max    191.0000   26.000000   20.000000   26.500000   19.000000   85.500000

# %%
df
# Out:
#      S.N        Roll                        Name    T1  T2  End sem    TA  \
# 0      1  BT20CSE001            ANIKET B AGRAWAL  22.0  17     24.0  18.0
# 1      2  BT20CSE002          KATTA RAKESH REDDY  12.0  13     23.0  11.0
# 2      3  BT20CSE003  CHIRAG RAJKUMAR BHANDAKKAR  20.0  15     18.0  18.0
# 3      4  BT20CSE004     Tejas Rajendra Donadkar  22.5  17     23.0  17.0
# 4      5  BT20CSE005  Utkarsh Sanjay Vishwakarma  23.0  17     22.5   4.0
# ..   ...         ...                         ...   ...  ..      ...   ...
# 186  187  BT20CSE207              Swapnil  Kabir  19.5  15     24.0  17.0
# 187  188  BT19CSE101                     NANDEEP   7.0  12      5.0   5.0
# 188  189  Bt18cse039               Aatram Sujith   4.0  14     11.5   5.5
# 189  190  BT20CSE096            VAIBHAV  GOKLANI   0.0   5      5.0   0.0
# 190  191  BT20CSE195       SHUBHANGI ASHOK RASAL   0.0   9      1.0   0.0
#
#     Grades  Total
# 0       AA   81.0
# 1       BC   59.0
# 2       BB   71.0
# ...
