# %%
from statistics import mean
from sklearn.datasets import load_iris
import pandas as pd
import warnings
import seaborn as sns
import matplotlib.pyplot as plt

# %%
m=[45, 25, 27, 32, 26]
print(mean(m))
# Out:
# 31

# %%
m1=[45, 25, 27, 32, 26, 31]
print(mean(m1))
# Out:
# 31

# %%
f=[24,26,12,22,16]

# %%
fsum=sum(f)
fsum
# Out:
# 100

# %%
df=pd.read_csv('E:\Data Science\Datasets\Correlation.csv')
df.head()
# Out:
#    Temperature  Sales
# 0        11.90    200
# 1        14.10    210
# 2        15.70    325
# 3        16.25    310
# 4        16.70    405

# %%
cc=df['Temperature'].corr(df['Sales'])
cc
# Out:
# 0.9273696161936916

# %%
warnings.filterwarnings(action="ignore")
csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris = pd.read_csv(csv_url, header = None)
col_names = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Species']
iris =  pd.read_csv(csv_url, names = col_names)
iris.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
sepalwidth = iris["Sepal_Width"]
species=iris["Species"]
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.boxplot(x=species, y=sepalwidth)
plt.title("Statistical Summary of Sepal Width")
plt.xlabel("Sepal_Width")
plt.show()

# %%
#plt.figure(figsize=(10,6))
sns.swarmplot(x='Sepal_Width',y='Petal_Width',data=iris)
sns.set(style="ticks")
plt.show()

# %%
sns.pairplot(iris)
