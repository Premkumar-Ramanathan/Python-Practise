# %% [markdown]
# # Task 1: Numpy Operations:

# %% [markdown]
# Question 1 Write a python program to convert an input dictionary into the numpy array. Keys of the input dictionary contain the column index like column0, column1 and so on and values of the dictionary contain the data.
#
# **Sample Input:**
#
# "{‘column0’: {‘First_Name’: ‘Akash’, ‘Second_Name’: ‘kumar’, ‘Interest’: ‘Coding’},
#  ‘column1’: {‘First_Name’: ‘Ayush’, ‘Second_Name’: ‘Sharma’, ‘Interest’: ‘Cricket’},
#  ‘column2’: {‘First_Name’: ‘Diksha’, ‘Second_Name’: ‘Sharma’, ‘Interest’: ‘Reading’},
#  ‘column3’: {‘First_Name’: ‘ Priyanka’, ‘Second_Name’: ‘Kumari’, ‘Interest’: ‘Dancing’}}"
#
# **Sample Output:**
#
# ![image.png](attachment:image.png)

# %%
# importing required librariess
import numpy as np
import ast
from ast import literal_eval
name_list=ast.literal_eval(input())

# Complete the code

# %% [markdown]
# # Task 2: Pandas Operations:

# %% [markdown]
# Write a python program to take a dictionary and column name as input. In the given dictionary keys are the column names and values are corresponding values in those columns. First create the dataframe using the given dictionary then make each value in the title case for the column taken as input and print the first 10 rows of the dataframe.
#
# **Sample Test Cases:**
#
# **Sample Input:**
# "{'Name': ['john', 'bODAY', 'minA', 'Peter', 'nicky'], 'Course': ['masters', 'graduate', 'graduate', 'Masters', 'Graduate'], 'Marks': [27, 23, 21, 23, 24]}"
# “Name”
#
# **Sample Output:**
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import ast 
dict_=ast.literal_eval(input())
col=input()  
# Complete the code

# %% [markdown]
# # Task 3: Pandas - Handling Missing Values:

# %% [markdown]
# Consider the employees data as given below:
#
# ![image.png](attachment:image.png)
#
# Create a dictionary where keys are column names and values are the corresponding statistics value of that column. Refer the below dictionary for which column which statistics to be used.
#
# {“Gender”:mode,”salary”:median,”bonus%”:median,”senior management”:mode,”Team”,mode}
#
# Now replace the missing values with given statistics for given columns and print the first 10 rows of the dataframe.
#
# **Sample Input:**
#
# Use Employee.csv dataset provided on the platform
#
# You can import the dataset using **pd.read_csv(file path)** command
#
# **Sample Output:**
# 1:
# ![image-2.png](attachment:image-2.png)
#
#
#
# 2:
#
# ![image-3.png](attachment:image-3.png)

# %%
import pandas as pd
df=pd.read_csv('path to file')
#Complete the code

# %% [markdown]
# # Task 4: Data Cleaning Analysis

# %% [markdown]
# ## Task 4.1

# %% [markdown]
# Consider a movie data set that contains information about the movies released, such as their genre, title,release_date and runtime. The column named ‘budget’ is a large number that is difficult to interpret. Write a Python program to create a new column named ‘scaled_budget’, where you put the values of the converted budget column into a million scale. Print the budget and scaled_budget columns after scale conversion (first five rows).

# %% [markdown]
# **Sample Input:**
#
# Use Movies.csv dataset provided on the platform
#
# You can import the dataset using pd.read_csv(file path) command
#
# **Sample Output:**
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd
df=pd.read_csv('path to file')
#Complete the code

# %% [markdown]
# ## Task 4.2:

# %% [markdown]
# Write a python program to print the original_language which has maximum average run time?
#
# **Input:**
#
# Use Movies.csv dataset provided on the platform
#
# You can import the dataset using pd.read_csv(file path) command
#
# **Sample Output:**
#
# ta

# %%
import pandas as pd
df=pd.read_csv('path to file')
#Complete the code

# %% [markdown]
# # Task 5: Matplotlib:

# %% [markdown]
# ## Task 5.1

# %% [markdown]
# Write a python program to perform a bivariate analysis using statistical summary plot of "runtime" column from given data with respect to original language and check whether outliers are present or not.
# Use appropriate figure size, rotate the x labels by 45 degree.
#
#
# **Input:**
#
# Use Movies.csv dataset provided on the platform
#
# You can import the dataset using pd.read_csv(file path) command
#
# **Sample Output:**
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
df=pd.read_csv("file path")
#Complete the code

# %% [markdown]
# ## Task 5.2

# %% [markdown]
# Using an appropriate graph, visualize the relationship between "revenue" and "budget" and identify whether these features are positively correlated, negatively correlated or not correlated.
#
# **Sample Input:**
#
# Use Movies.csv dataset provided on the platform
#
# You can import the dataset using pd.read_csv(file path) command
#
# **Sample Output:**
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
df=pd.read_csv("file path")
#Complete the code

# %% [markdown]
# # Task 6: Seaborn

# %% [markdown]
# ## Task 6.1

# %% [markdown]
# Perform the multivariate analysis by checking the correlation matrix using heatmap for all the numerical features given dataset. Also annotate the values of correlation coefficient on the heatmap. Use figsize (8,6).
#
# **Input:**
#
# Use Movies.csv dataset provided on the platform
#
# You can import the dataset using pd.read_csv(file path) command
#
# **Sample Output:**
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("file path")
#Complete the code

# %% [markdown]
# ## Task 6.2

# %% [markdown]
# Write a python program to create a frequency distribution plot of "revenue" column from given data with bins as 5.
#
# **Input:**
#
# Use Movies.csv dataset provided on the platform
#
# You can import the dataset using **pd.read_csv(file path)** command
#
# **Sample Output:**
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("file path")
#Complete the code

# %% [markdown]
# # Task 7: Data Cleaning and Analysis

# %% [markdown]
# Using pandas, load and clean the data set of stock prices that is provided to you as a CSV file). Perform tasks such as handling missing values and removing duplicate rows. Use NumPy to calculate the daily returns of the stock prices. Use matplotlib to create a line plot of the daily returns over time.
#
# **Input:**
#
# Use AAPL.csv dataset provided on the platform
#
# You can import the dataset using **pd.read_csv('file path')** command
#
# **Output**
#
# ![image.png](attachment:image.png)
