# %%
#Import the required Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data Reading & Data Types

# %%
#Read the data in pandas
inp0= pd.read_csv("E:\Data Science\Datasets\Attribute+DataSet.csv")
inp1= pd.read_csv("E:\Data Science\Datasets\Dress+Sales.csv")

# %% [markdown]
# You have “Attribute DataSet” which contains a column named “Price”. Choose the correct statement from the following about its data type and variable type.
# - Integer type and numerical variable
# - Object type and categorical ordinal variable
# - Object type and categorical nominal variable
# - Float type and categorical variable.

# %% [markdown]
# There is another column in “Attribute DataSet” named as “Recommendation”, choose the correct statement about its data type and variable type.
# - Integer type and categorical
# - Object type and categorical
# - Integer type and continuous numerical
# - Object type only.

# %% [markdown]
# Which of the following column do you think are of no use in “Attribute DataSet”.
# - Dress_ID
# - Price
# - Size and material
# - NeckLine
# - None of the above

# %%
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %%
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dress_ID        479 non-null    int64
#  1   Style           479 non-null    object
#  2   Price           477 non-null    object
#  3   Rating          479 non-null    float64
#  4   Size            479 non-null    object
#  5   Season          477 non-null    object
#  6   NeckLine        476 non-null    object
#  7   SleeveLength    477 non-null    object
#  8   Material        360 non-null    object
#  9   FabricType      223 non-null    object
#  10  Decoration      255 non-null    object
#  11  Pattern Type    377 non-null    object
#  12  Recommendation  479 non-null    int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 48.8+ KB

# %%
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    int64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  479 non-null    object
#  9   14-09-2013  479 non-null    object
#  10  16-09-2013  479 non-null    object
#  11  18-09-2013  479 non-null    object
#  12  20-09-2013  479 non-null    object
#  13  22-09-2013  479 non-null    object
#  14  24-09-2013  479 non-null    int64
#  15  26-09-2013  257 non-null    float64
#  16  28-09-2013  479 non-null    int64
#  17  30-09-2013  222 non-null    float64
#  18  10-02-2013  220 non-null    float64
# ...

# %%
inp1=inp1.fillna(0)

# %% [markdown]
# ### Fixing the Rows and Columns

# %% [markdown]
# As you can see, there is a column in “Attribute Dataset” named as ‘Size’. This column contains the values in abbreviation format. Write a code in Python to convert the followings:
#
# - M into  “Medium”
# - L into  “Large”
# - XL into “Extra large”
# - free into “Free”
# - S, s & small into “Small”.
#
# Now once you are done with changes in the dataset, what is the value of the lowest percentage, the highest percentage and the percentage of Small size categories in the column named “Size”?

# %%
# Column fixing, correcting size abbreviation. count the percentage of each size category in "Size" column.
size_mapping={
    'M': 'Medium',
    'L': 'Large',
    'XL': 'Extra large',
    'free': 'Free',
    'S': 'Small',
    's': 'Small',
    'small': 'Small'
}
inp0['Size']=inp0['Size'].replace(size_mapping)
inp0
# Out:
#        Dress_ID    Style    Price  Rating    Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6  Medium  Summer     o-neck
# 1    1212192089   Casual      Low     0.0   Large  Summer     o-neck
# 2    1190380701  vintage     High     0.0   Large  Automn     o-neck
# 3     966005983    Brief  Average     4.6   Large  Spring     o-neck
# 4     876339541     cute      Low     4.5  Medium  Summer     o-neck
# ..          ...      ...      ...     ...     ...     ...        ...
# 474   990559192    Brief  Average     4.7  Medium  winter     o-neck
# 475   713391965   Casual      Low     4.7  Medium  Spring     o-neck
# 476   532874347   Casual  Average     4.7  Medium  Summer     v-neck
# 477   655464934   Casual  Average     4.6   Large  winter  boat-neck
# 478   919930954   Casual      Low     4.4    Free  Summer     v-neck
#
#     SleeveLength       Material  FabricType  Decoration Pattern Type  \
# ...

# %%
size_distribution = inp0['Size'].value_counts(normalize=True) * 100
# Find the lowest and highest percentage
lowest_percentage = size_distribution.min()
highest_percentage = size_distribution.max()
percentage_small = size_distribution.get('Small', 0)

# %%
print(lowest_percentage)
print(highest_percentage)
print(percentage_small)
# Out:
# 2.9227557411273484
# 35.699373695198325
# 7.515657620041753

# %%
# Print the value counts of each category in "Size" column.
print(inp0['Size'].value_counts())
# Out:
# Medium         171
# Free           165
# Large           93
# Small           36
# Extra large     14
# Name: Size, dtype: int64

# %% [markdown]
# ### Impute/Remove Missing values

# %%
# Print the null count of each variables of inp0 and inp1.
inp0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# dtype: int64

# %% [markdown]
# You are given another dataset named “Dress Sales”. Now if you observe the datatypes of the columns using ‘inp1.info()’ command, you can identify that there are certain columns defined as object data type though they primarily consist of numeric data.
#
# Now if you try and convert these object data type columns into numeric data type(float), you will come across an error message. Try to correct this error.

# %%
# Print the data types information of inp1 i.e. "Dress Sales" data.
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    int64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  479 non-null    object
#  9   14-09-2013  479 non-null    object
#  10  16-09-2013  479 non-null    object
#  11  18-09-2013  479 non-null    object
#  12  20-09-2013  479 non-null    object
#  13  22-09-2013  479 non-null    object
#  14  24-09-2013  479 non-null    int64
#  15  26-09-2013  257 non-null    float64
#  16  28-09-2013  479 non-null    int64
#  17  30-09-2013  222 non-null    float64
#  18  10-02-2013  220 non-null    float64
# ...

# %%
# Calculate the percentage of null values column-wise
null_percentage = (inp1.isnull().sum() / len(inp1)) * 100
print(null_percentage)
# Out:
# Dress_ID       0.000000
# 29-08-2013     0.000000
# 31-08-2013     0.000000
# 09-02-2013     0.000000
# 09-04-2013     0.000000
# 09-06-2013     0.000000
# 09-08-2013     0.000000
# 09-10-2013     0.000000
# 09-12-2013     0.000000
# 14-09-2013     0.000000
# 16-09-2013     0.000000
# 18-09-2013     0.000000
# 20-09-2013     0.000000
# 22-09-2013     0.000000
# 24-09-2013     0.000000
# 26-09-2013    46.346555
# 28-09-2013     0.000000
# 30-09-2013    53.653445
# 10-02-2013    54.070981
# 10-04-2013    53.862213
# 10-06-2013     0.000000
# 10-08-2013    53.235908
# 10-10-2013    53.235908
# 10-12-2013     0.000000
# dtype: float64

# %%
# Do the required changes in the "Dress Sales" data set to get null values on string values.

# %%
# Convert the object type columns in "Dress Sales" into float type of data type.
col_list=[]
for col in inp1.columns:
    if inp1[col].dtype=='int64':
        col_list.append(inp1[col].name)

for col in col_list:
    inp1[col]=inp1[col].astype('float64')

inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    float64
#  1   29-08-2013  479 non-null    float64
#  2   31-08-2013  479 non-null    float64
#  3   09-02-2013  479 non-null    float64
#  4   09-04-2013  479 non-null    float64
#  5   09-06-2013  479 non-null    float64
#  6   09-08-2013  479 non-null    float64
#  7   09-10-2013  479 non-null    float64
#  8   09-12-2013  479 non-null    float64
#  9   14-09-2013  479 non-null    float64
#  10  16-09-2013  479 non-null    float64
#  11  18-09-2013  479 non-null    float64
#  12  20-09-2013  479 non-null    float64
#  13  22-09-2013  479 non-null    float64
#  14  24-09-2013  479 non-null    float64
#  15  26-09-2013  479 non-null    float64
#  16  28-09-2013  479 non-null    float64
#  17  30-09-2013  479 non-null    float64
# ...

# %% [markdown]
# When you see the null counts in “Dress Sales” dataset after performing all the operations that have been mentioned in jupyter notebook, you will find that there are some columns in “Dress Sales” data where there are more than 40% of missing values. Based on your understanding of dealing with missing values do the following steps.

# %%
# Print the null percetange of each column of inp1.
null_percentage = (inp1.isnull().sum() / len(inp1)) * 100
print(null_percentage)
# Out:
# Dress_ID      0.0
# 29-08-2013    0.0
# 31-08-2013    0.0
# 09-02-2013    0.0
# 09-04-2013    0.0
# 09-06-2013    0.0
# 09-08-2013    0.0
# 09-10-2013    0.0
# 09-12-2013    0.0
# 14-09-2013    0.0
# 16-09-2013    0.0
# 18-09-2013    0.0
# 20-09-2013    0.0
# 22-09-2013    0.0
# 24-09-2013    0.0
# 26-09-2013    0.0
# 28-09-2013    0.0
# 30-09-2013    0.0
# 10-02-2013    0.0
# 10-04-2013    0.0
# 10-06-2013    0.0
# 10-08-2013    0.0
# 10-10-2013    0.0
# 10-12-2013    0.0
# dtype: float64

# %%
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %%
inp1.head()
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1.006033e+09      2114.0      2274.0      2491.0      2660.0      2727.0
# 1  1.212192e+09       151.0       275.0       570.0       750.0       813.0
# 2  1.190381e+09         6.0         7.0         7.0         7.0         8.0
# 3  9.660060e+08      1005.0      1128.0      1326.0      1455.0      1507.0
# 4  8.763395e+08       996.0      1175.0      1304.0      1396.0      1432.0
#
#    09-08-2013  09-10-2013  09-12-2013  14-09-2013  ...  24-09-2013  \
# 0      2887.0      2930.0      3119.0      3204.0  ...      3554.0
# 1      1066.0      1164.0      1558.0      1756.0  ...      2710.0
# 2         8.0         9.0        10.0        10.0  ...        11.0
# 3      1621.0      1637.0      1723.0      1746.0  ...      1878.0
# 4      1559.0      1570.0      1638.0      1655.0  ...      2032.0
#
#    26-09-2013  28-09-2013  30-09-2013  10-02-2013  10-04-2013  10-06-2013  \
# ...

# %%
# Drop the columns in "Dress Sales" which have more than 40% of missing values.
null_percentage = (inp1.isnull().sum() / len(inp1)) * 100
print(null_percentage)
# Out:
# Dress_ID       0.000000
# 29-08-2013     0.000000
# 31-08-2013     0.000000
# 09-02-2013     0.000000
# 09-04-2013     0.000000
# 09-06-2013     0.000000
# 09-08-2013     0.000000
# 09-10-2013     0.000000
# 09-12-2013     0.000000
# 14-09-2013     0.000000
# 16-09-2013     0.000000
# 18-09-2013     0.000000
# 20-09-2013     0.000000
# 22-09-2013     0.000000
# 24-09-2013     0.000000
# 26-09-2013    46.346555
# 28-09-2013     0.000000
# 30-09-2013    53.653445
# 10-02-2013    54.070981
# 10-04-2013    53.862213
# 10-06-2013     0.000000
# 10-08-2013    53.235908
# 10-10-2013    53.235908
# 10-12-2013     0.000000
# dtype: float64

# %% [markdown]
# You should categorise the dates into seasons in “Dress Sales” data to simplify the analysis according to the following criteria:
# - June, July and August: Summer.
# - September, October and November: Autumn.
# - December, January and February: WInter.
# - March, April and May: Spring.

# %%
# Create the four seasons columns in inp1, according to the above criteria.
inp1['Summer'] = inp1.apply(lambda x: x['29-08-2013'] + x['31-08-2013']+ x['09-06-2013']+ x['09-08-2013']+ x['10-06-2013']+ x['10-08-2013'], axis=1)
inp1['Autumn'] = inp1.apply(lambda x: x['09-10-2013'] + x['14-09-2013']+ x['16-09-2013']+ x['18-09-2013']+ x['20-09-2013']+ x['22-09-2013']+ x['24-09-2013']+ x['26-09-2013']+ x['28-09-2013']+ x['30-09-2013'] +x['10-10-2013'], axis=1)
inp1['Winter'] = inp1.apply(lambda x: x['09-02-2013'] + x['09-12-2013']+ x['10-02-2013']+ x['10-12-2013'], axis=1)
inp1['Spring'] = inp1.apply(lambda x: x['09-04-2013']+ x['10-04-2013'], axis=1)
inp1.head()
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1.006033e+09      2114.0      2274.0      2491.0      2660.0      2727.0
# 1  1.212192e+09       151.0       275.0       570.0       750.0       813.0
# 2  1.190381e+09         6.0         7.0         7.0         7.0         8.0
# 3  9.660060e+08      1005.0      1128.0      1326.0      1455.0      1507.0
# 4  8.763395e+08       996.0      1175.0      1304.0      1396.0      1432.0
#
#    09-08-2013  09-10-2013  09-12-2013  14-09-2013  ...  10-02-2013  \
# 0      2887.0      2930.0      3119.0      3204.0  ...      3795.0
# 1      1066.0      1164.0      1558.0      1756.0  ...      3475.0
# 2         8.0         9.0        10.0        10.0  ...        11.0
# 3      1621.0      1637.0      1723.0      1746.0  ...      1929.0
# 4      1559.0      1570.0      1638.0      1655.0  ...      2387.0
#
#    10-04-2013  10-06-2013  10-08-2013  10-10-2013  10-12-2013  Spring  \
# ...

# %%
# calculate the sum of sales in each seasons in inp1 i.e. "Dress Sales".
inp1
# Out:
#          Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0    1.006033e+09        2114        2274        2491        2660        2727
# 1    1.212192e+09         151         275         570         750         813
# 2    1.190381e+09           6           7           7           7           8
# 3    9.660060e+08        1005        1128        1326        1455        1507
# 4    8.763395e+08         996        1175        1304        1396        1432
# ..            ...         ...         ...         ...         ...         ...
# 474  9.905592e+08           0           0           0          60          62
# 475  7.133920e+08           0           0           0         560         554
# 476  5.328743e+08           0           0           0         734         728
# 477  6.554649e+08           0           0           0         254         259
# 478  9.199310e+08           0           0           0         538         545
#
# ...

# %% [markdown]
# Now let's merge inp1 with inp0 with left join manner, so that the information of inp0 should remain intact.

# %%
# Merge inp0 with inp1 into inp0. this is also called left merge.
inp0 = pd.merge(left=inp0,right=inp1, how='left', left_on='Dress_ID', right_on='Dress_ID')
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  ... 10-02-2013 10-04-2013  10-06-2013  \
# 0            NaN    chiffon  ...     3795.0     3832.0      3897.0
# 1     microfiber        NaN  ...     3475.0     3654.0      3911.0
# 2       polyster        NaN  ...       11.0       11.0        11.0
# 3           silk    chiffon  ...     1929.0     1941.0      1952.0
# 4  chiffonfabric    chiffon  ...     2387.0     2459.0      2544.0
#
#    10-08-2013  10-10-2013  10-12-2013  Spring   Summer   Winter   Autumn
# ...

# %%
inp0.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'Material', 'FabricType', 'Decoration', 'Pattern Type',
#        'Recommendation', '29-08-2013', '31-08-2013', '09-02-2013',
#        '09-04-2013', '09-06-2013', '09-08-2013', '09-10-2013', '09-12-2013',
#        '14-09-2013', '16-09-2013', '18-09-2013', '20-09-2013', '22-09-2013',
#        '24-09-2013', '26-09-2013', '28-09-2013', '30-09-2013', '10-02-2013',
#        '10-04-2013', '10-06-2013', '10-08-2013', '10-10-2013', '10-12-2013',
#        'Spring', 'Summer', 'Winter', 'Autumn'],
#       dtype='object')

# %%
# Now Drop the Date columns from inp0 as it is already combined into four seasons.
#inp0.drop(inp0.loc['29-08-2013','31-08-2013','09-06-2013','09-08-2013'].columns, axis= 1, inplace= True)
#inp0.isnull().sum()
col_remove=['29-08-2013','31-08-2013','09-02-2013','09-04-2013','09-06-2013', '09-08-2013', '09-10-2013', '09-12-2013','14-09-2013', '16-09-2013', '18-09-2013', '20-09-2013', '22-09-2013','24-09-2013', '26-09-2013', '28-09-2013', '30-09-2013', '10-02-2013','10-04-2013', '10-06-2013', '10-08-2013', '10-10-2013', '10-12-2013']
inp0=inp0.drop(columns=col_remove)
inp0
# Out:
#        Dress_ID    Style    Price  Rating    Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6  Medium  Summer     o-neck
# 1    1212192089   Casual      Low     0.0   Large  Summer     o-neck
# 2    1190380701  vintage     High     0.0   Large  Automn     o-neck
# 3     966005983    Brief  Average     4.6   Large  Spring     o-neck
# 4     876339541     cute      Low     4.5  Medium  Summer     o-neck
# ..          ...      ...      ...     ...     ...     ...        ...
# 474   990559192    Brief  Average     4.7  Medium  winter     o-neck
# 475   713391965   Casual      Low     4.7  Medium  Spring     o-neck
# 476   532874347   Casual  Average     4.7  Medium  Summer     v-neck
# 477   655464934   Casual  Average     4.6   Large  winter  boat-neck
# 478   919930954   Casual      Low     4.4    Free  Summer     v-neck
#
#     SleeveLength       Material  FabricType  Decoration Pattern Type  \
# ...

# %%
inp0['Total Sales']=inp0['Spring']+inp0['Summer']+inp0['Winter']+inp0['Autumn']
inp0
# Out:
#        Dress_ID    Style    Price  Rating    Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6  Medium  Summer     o-neck
# 1    1212192089   Casual      Low     0.0   Large  Summer     o-neck
# 2    1190380701  vintage     High     0.0   Large  Autumn     o-neck
# 3     966005983    Brief  Average     4.6   Large  Spring     o-neck
# 4     876339541     cute      Low     4.5  Medium  Summer     o-neck
# ..          ...      ...      ...     ...     ...     ...        ...
# 474   990559192    Brief  Average     4.7  Medium  Winter     o-neck
# 475   713391965   Casual      Low     4.7  Medium  Spring     o-neck
# 476   532874347   Casual  Average     4.7  Medium  Summer     v-neck
# 477   655464934   Casual  Average     4.6   Large  Winter  boat-neck
# 478   919930954   Casual      Low     4.4    Free  Summer     v-neck
#
#     SleeveLength       Material  FabricType  Decoration Pattern Type  \
# ...

# %%
inp0.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'Material', 'FabricType', 'Decoration', 'Pattern Type',
#        'Recommendation', 'Spring', 'Summer', 'Winter', 'Autumn'],
#       dtype='object')

# %% [markdown]
# Print the null count of inp0 to get the idea about the missing values in data set.

# %%
# Print the null count of each columns in inp0 dataframe i.e. combined data frame of inp0 and inp1 without date columns.
inp0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# Spring              0
# Summer              0
# Winter              0
# Autumn              0
# dtype: int64

# %%
#You can see that there are two types of variables one with a large number of missing values and another is very less number
#of missing values. These two columns can be categorized as:
#Type-1: Missing values are very less (around 2 or 3 missing values): Price, Season, NeckLine, SleeveLength, Winter and Autumn. 
#Type-2: Missing values are large in numbers (more than 15%): Material, FabricType, Decoration and Pattern Type.

# %%
# Deal with the missing values of Type-1 columns: Price, Season, NeckLine, SleeveLength, Winter and Autumn.
mode=inp0['Price'].mode()[0]
inp0['Price'].fillna(mode,inplace=True)

mode=inp0['Season'].mode()[0]
inp0['Season'].fillna(mode,inplace=True)

mode=inp0['NeckLine'].mode()[0]
inp0['NeckLine'].fillna(mode,inplace=True)

mode=inp0['SleeveLength'].mode()[0]
inp0['SleeveLength'].fillna(mode,inplace=True)

# %%
inp0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               0
# Rating              0
# Size                0
# Season              0
# NeckLine            0
# SleeveLength        0
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# Spring              0
# Summer              0
# Winter              0
# Autumn              0
# dtype: int64

# %%
# Deal with the missing values for Type-2 columns: Material, FabricType, Decoration and Pattern Type.
mode=inp0['Material'].mode()[0]
inp0['Material'].fillna(mode,inplace=True)

mode=inp0['FabricType'].mode()[0]
inp0['FabricType'].fillna(mode,inplace=True)

mode=inp0['Decoration'].mode()[0]
inp0['Decoration'].fillna(mode,inplace=True)

mode=inp0['Pattern Type'].mode()[0]
inp0['Pattern Type'].fillna(mode,inplace=True)

inp0.isnull().sum()
# Out:
# Dress_ID          0
# Style             0
# Price             0
# Rating            0
# Size              0
# Season            0
# NeckLine          0
# SleeveLength      0
# Material          0
# FabricType        0
# Decoration        0
# Pattern Type      0
# Recommendation    0
# Spring            0
# Summer            0
# Winter            0
# Autumn            0
# dtype: int64

# %% [markdown]
# ### Standardise value

# %% [markdown]
# In the given dataset, there are certain discrepancies with the categorical names such as irregular spellings. Choose the correct option of columns with irregular categories and update them.
#
# - Season, NeckLine
# - Price, Material
# - fabricType, Decoration
# - Season, SleeveLength

# %%
#correcting the spellings.
inp0['Style'].value_counts()
# Out:
# Casual      219
# Sexy         66
# party        51
# cute         44
# vintage      25
# bohemian     23
# Brief        17
# work         17
# sexy          7
# Novelty       6
# Flare         2
# OL            1
# fashion       1
# Name: Style, dtype: int64

# %%
#correcting the Spellings.
inp0['Style']=inp0['Style'].replace('sexy','Sexy')
inp0['Style'].value_counts()
# Out:
# Casual      219
# Sexy         73
# party        51
# cute         44
# vintage      25
# bohemian     23
# Brief        17
# work         17
# Novelty       6
# Flare         2
# OL            1
# fashion       1
# Name: Style, dtype: int64

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Categorical Unordered Univariate Analysis

# %% [markdown]
# There is a column named ‘Style’ in ‘Attribute Dataset’ which consists of the different style categories of the women apparels. Certain categories whose total sale is less than 50000 across all the seasons is considered under one single category as ‘Others’.

# %% [markdown]
# Which of the following categories in ‘Style’ column can be grouped into ‘Others’ category? and perform the grouping operation in the notebook for further analysis.
# - Flare, fashion
# - Novelty, bohemian
# - OL, fashion, work
# - Novelty, fashion, Flare

# %%
# Group "Style" categories into "Others" which have less than 50000 sales across all the seasons.
inp0['Style'].value_counts()
# Out:
# Casual      219
# Sexy         66
# party        51
# cute         44
# vintage      25
# bohemian     23
# Brief        17
# work         17
# sexy          7
# Novelty       6
# Flare         2
# OL            1
# fashion       1
# Name: Style, dtype: int64

# %% [markdown]
# What is the percentage of “cute” and “Others” category in “Style” column in “Attribute DataSet” respectively?
# - 46%, 5%
# - 9%, 2.1%
# - 2.1%, 5%
# - 13.8%, 9%

# %%
# Calculate the percentage of each categories in the "Style" variable.
grouped = inp0.groupby('Style').agg({'Total Sales':'sum'})
#result = grouped['Total Sales'].sum()
sorted_result = grouped.sort_values(by='Total Sales', ascending=True)
print(sorted_result)
# Out:
#           Total Sales
# Style
# OL              382.0
# fashion         395.0
# Flare          2898.0
# Novelty       14995.0
# bohemian      67047.0
# work          91195.0
# Brief        145630.0
# party        152092.0
# vintage      190162.0
# cute         409247.0
# Sexy         574345.0
# Casual      1123409.0

# %%
threshold = 50000

# Calculate the sum of 'Value' for each 'Category'
category_sums = inp0.groupby('Style')['Total Sales'].transform('sum')

# Categorize 'Category' values as "Others" if the sum is below the threshold
inp0['Style_Category'] = inp0['Style'].where(category_sums > threshold, 'Others')

# %%
grouped = inp0.groupby('Style_Category').agg({'Total Sales':'sum'})
#result = grouped['Total Sales'].sum()
sorted_result = grouped.sort_values(by='Total Sales', ascending=True)
print(sorted_result)
# Out:
#                 Total Sales
# Style_Category
# Others              18670.0
# bohemian            67047.0
# work                91195.0
# Brief              145630.0
# party              152092.0
# vintage            190162.0
# cute               409247.0
# Sexy               574345.0
# Casual            1123409.0

# %%
s = inp0['Total Sales'].sum()
s
# Out:
# 2771797.0

# %%
print(inp0.Style.value_counts(normalize=True))
inp0.Style.value_counts(normalize=True).plot.barh()
plt.show()
# Out:
# Casual      0.457203
# Sexy        0.152401
# party       0.106472
# cute        0.091858
# vintage     0.052192
# bohemian    0.048017
# Brief       0.035491
# work        0.035491
# Novelty     0.012526
# Flare       0.004175
# OL          0.002088
# fashion     0.002088
# Name: Style, dtype: float64

# %% [markdown]
# Similarly Club Neckline, SLeeve length categories into "Others" which have less than 50000 sales across all the seasons.

# %%
# Group "Neckline" categories into "Others" which have less than 50000 sales across all the seasons.

# %%
# Group "Sleeve length" categories into "Others" which have less than 50000 sales across all the seasons.

# %% [markdown]
# Club material, fabrictype, patterntype and decoration categories into "Others" which have less than 25000 sales across all the seasons

# %%
# Group "material" categories into "Others" which have less than 25000 sales across all the seasons.

# %%
# Group "fabric type" categories into "Others" which have less than 25000 sales across all the seasons.

# %%
# Group "patern type" categories into "Others" which have less than 25000 sales across all the seasons.

# %%
# Group "decoration" categories into "Others" which have less than 25000 sales across all the seasons.

# %% [markdown]
# ### Caregorical Ordered Univariate Analysis

# %% [markdown]
# Which of the following is an unordered variable in “Attribute DataSet”.
# - Style
# - Price
# - Season
# - Size

# %% [markdown]
# ### Numerical variable Univariate analysis:

# %% [markdown]
# What is the approximate difference between the maximum value and 75th percentile in “Autumn” column.
# - Approx 54000
# - Approx 55000
# - Approx 52000
# - Approx 50000

# %%
# Describe the numerical variale: "Autumn".
inp0['Autumn'].describe()
# Out:
# count      479.000000
# mean      3116.315240
# std       5733.652046
# min          1.000000
# 25%        493.000000
# 50%       1425.000000
# 75%       3272.500000
# max      68387.000000
# Name: Autumn, dtype: float64

# %%
s=inp0['Autumn'].sum()
s
# Out:
# 1492715.0

# %%
# plot the boxplot of "Autumn" column.
plt.figure(figsize=(6, 4))  # Optional: Adjust the figure size
plt.boxplot(inp0['Autumn'])

# Set labels and title
plt.xticks([1], ['Autumn'])
plt.title('Boxplot of Autumn')
# Out:
# Text(0.5, 1.0, 'Boxplot of Autumn')

# %% [markdown]
# Which of the following season has the highest difference between the maximum value and 99th quantile of sales?
# - Winter
# - Summer
# - Spring
# - Autumn

# %%
# Find the maximum and 99th percentile of Winter season.

# %%
# Find the maximum and 99th percentile of Summer season.

# %%
# Find the maximum and 99th percentile of Spring season.

# %%
# Find the maximum and 99th percentile of Autumn season.

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numerical- Categorical analysis

# %% [markdown]
# Which of the following “Price” category has the lowest average value of rating?
# - very-high
# - Medium
# - Low
# - High

# %%
# Find the Mean of Ratings for each Price category.

# %% [markdown]
# What is the median of the rating of “vintage” category in Style column?
# - 4.6
# - 4.7
# - 4.55
# - 0.00

# %%
# Find the median of Ratings for each Style category.

# %% [markdown]
# Which of the following season has the highest average value of sale for “Recommendation” value equals to 1.
# - Summer
# - Spring
# - Autumn
# - Winter

# %%
# Summer sale vs Recommendation.

# %%
# Spring sale vs Recommendation.

# %%
# Autumn sale vs Recommendation.

# %%
# Winter sale vs Recommendation.

# %% [markdown]
# ### Categorical categorical bivariate analysis

# %% [markdown]
# Which of the following size categories has the highest positive recommendations?
# - Medium and extra large
# - Extra large and small
# - Free and small
# - Free and medium

# %%
# Size vs Recommendation.

# %% [markdown]
# ### Multivariate analysis

# %% [markdown]
# Which of the following pair of “Style” and “Price” category has the highest average of positive recommendations?
# - Price: medium and style: vintage
# - Price: medium and style: cute
# - Price: very high and style: party
# - Price: low and style: sexy

# %%
# plot the heat map of Style, price and Recommendation.

# %% [markdown]
# Which of the following material type has no recommendation in summer and winter seasons?
# - Mix and Milksilk
# - Nylon and Rayon
# - Microfiber and Silk
# - Milksilk and Microfiber

# %%
# plot the heat map of Season, material and Recommendation.

# %%
inp0
# Out:
#        Dress_ID    Style    Price  Rating    Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6  Medium  Summer     o-neck
# 1    1212192089   Casual      Low     0.0   Large  Summer     o-neck
# 2    1190380701  vintage     High     0.0   Large  Autumn     o-neck
# 3     966005983    Brief  Average     4.6   Large  Spring     o-neck
# 4     876339541     cute      Low     4.5  Medium  Summer     o-neck
# ..          ...      ...      ...     ...     ...     ...        ...
# 474   990559192    Brief  Average     4.7  Medium  Winter     o-neck
# 475   713391965   Casual      Low     4.7  Medium  Spring     o-neck
# 476   532874347   Casual  Average     4.7  Medium  Summer     v-neck
# 477   655464934   Casual  Average     4.6   Large  Winter  boat-neck
# 478   919930954   Casual      Low     4.4    Free  Summer     v-neck
#
#     SleeveLength       Material  FabricType  Decoration Pattern Type  \
# ...
